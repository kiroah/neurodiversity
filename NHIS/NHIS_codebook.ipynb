# %% [markdown]
# # NHIS codebook import
# Python script to scrape codebooks (PDF) from different years and merge them. Output is CSV

# %%
pip install tabula-py
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tabula-py
#   Downloading tabula_py-2.9.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: pandas>=0.25.3 in c:\users\hiron\appdata\roaming\python\python311\site-packages (from tabula-py) (1.5.3)
# Requirement already satisfied: numpy in c:\users\hiron\appdata\roaming\python\python311\site-packages (from tabula-py) (1.25.2)
# Requirement already satisfied: distro in c:\programdata\anaconda3\lib\site-packages (from tabula-py) (1.8.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\hiron\appdata\roaming\python\python311\site-packages (from pandas>=0.25.3->tabula-py) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hiron\appdata\roaming\python\python311\site-packages (from pandas>=0.25.3->tabula-py) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\hiron\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.1->pandas>=0.25.3->tabula-py) (1.16.0)
# Downloading tabula_py-2.9.0-py3-none-any.whl (12.0 MB)
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.0 MB 640.0 kB/s eta 0:00:19
#    ---------------------------------------- 0.1/12.0 MB 656.4 kB/s eta 0:00:19
#     --------------------------------------- 0.2/12.0 MB 1.5 MB/s eta 0:00:09
#    - -------------------------------------- 0.5/12.0 MB 3.0 MB/s eta 0:00:04
#    --- ------------------------------------ 1.1/12.0 MB 5.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.7/12.0 MB 6.6 MB/s eta 0:00:02
#    ------- -------------------------------- 2.3/12.0 MB 7.4 MB/s eta 0:00:02
#    --------- ------------------------------ 2.9/12.0 MB 8.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.6/12.0 MB 9.1 MB/s eta 0:00:01
#    -------------- ------------------------- 4.4/12.0 MB 10.0 MB/s eta 0:00:01
#    ------------------ --------------------- 5.4/12.0 MB 10.8 MB/s eta 0:00:01
#    -------------------- ------------------- 6.1/12.0 MB 11.5 MB/s eta 0:00:01
#    ------------------------ --------------- 7.3/12.0 MB 12.6 MB/s eta 0:00:01
#    -------------------------- ------------- 7.9/12.0 MB 12.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.8/12.0 MB 13.1 MB/s eta 0:00:01
#    -------------------------------- ------- 9.9/12.0 MB 13.7 MB/s eta 0:00:01
#    ------------------------------------ --- 11.0/12.0 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------------  12.0/12.0 MB 19.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.0/12.0 MB 18.2 MB/s eta 0:00:00
# Installing collected packages: tabula-py
# Successfully installed tabula-py-2.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jpype1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting jpype1
#   Downloading JPype1-1.5.0-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: packaging in c:\users\hiron\appdata\roaming\python\python311\site-packages (from jpype1) (24.0)
# Downloading JPype1-1.5.0-cp311-cp311-win_amd64.whl (351 kB)
#    ---------------------------------------- 0.0/351.5 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/351.5 kB 640.0 kB/s eta 0:00:01
#    --------- ----------------------------- 81.9/351.5 kB 907.3 kB/s eta 0:00:01
#    ------------------------------- -------- 276.5/351.5 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 351.5/351.5 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: jpype1
# Successfully installed jpype1-1.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import tabula
import pandas as pd

# %%
# List of codebooks and their path, currently grouped by child and adult. 
codebook_collections = {
    'source/child-codebook': {
        '22': 'source/child-summary22.pdf',
        '21': 'source/child-summary21.pdf',
        '20': 'source/child-summary20.pdf',
        '19': 'source/child-summary19.pdf',
    },
    'source/adult-codebook': {
        '22': 'source/adult-summary22.pdf',
        '21': 'source/adult-summary21.pdf',
        '20': 'source/adult-summary20.pdf',
        '19': 'source/adult-summary19.pdf',

    }
}

#List of columns in the PDF
data_columns = [ "Variable",
            "Question #",
            "Variable Name",
            "Source Variables",
            "Description",
            "Type",
            "Location",
            "Length"]

col_mapping = dict(zip(range(0,8), data_columns))


for cc_index, cc_value in codebook_collections.items():
    export_table = pd.DataFrame(columns=data_columns)
    for codebook_index, codebook in cc_value.items():
        base_table = pd.DataFrame(columns=range(0,7))
        
        #Import/scrape PDF, follwed by iterating through the tables in the PDF into one dataframe.
        pdf_tables = tabula.read_pdf(codebook, pages='all', multiple_tables=True, pandas_options={'header':'None'})
        for i, table in enumerate(pdf_tables):
            base_table = pd.concat([base_table, table], ignore_index=True, axis=0)
        
        base_table = base_table.rename(columns=col_mapping)
        base_table.drop_duplicates(inplace=True)
        base_table.drop(axis=0, index=0,inplace=True)
        base_table[codebook_index] = 'x'
        #There are some garbage imports (in 2019). Cleaning them up
        base_table = base_table.dropna(subset=['Type'],axis=0)
        
        #For initial PDF, just concat and don't do anything complicated
        if export_table.shape[0] == 0:
            export_table = pd.concat([export_table,base_table],axis=0)
        #For subsequent PDFs, first merge with an outer join, followed by dropping duplicates (using variable name), and then merge the description columns into one
        else:
            export_table = pd.merge(export_table,base_table,on='Variable Name',how='outer',suffixes=('', '_x'))
            export_table.drop_duplicates(subset=['Variable Name'],inplace=True,keep='first')
            for column in data_columns:
                if column != "Variable Name":
                    export_table[column] = export_table[column].combine_first(export_table[column + '_x'])
                    export_table = export_table.drop(column+'_x',axis=1)
    export_table.to_csv(cc_index +".csv")

# %%
export_table
# Out:
#     Variable     Question # Variable Name Source Variables  \
# 0          1            NaN       RECTYPE              NaN
# 1          2            NaN       SRVY_YR              NaN
# 2          3            NaN           HHX              NaN
# 3          4            NaN        WTFA_A              NaN
# 4          1         Recode        URBRRL              NaN
# ..       ...            ...           ...              ...
# 957      2.0  ART.0020.00.3       JNTPN_A              NaN
# 958      3.0  ART.0030.00.3     ARTHLMT_A              NaN
# 959      4.0  ART.0040.00.3     ARTHWRK_A              NaN
# 960      5.0  ART.0050.00.3      ARTHWT_A              NaN
# 961      6.0  ART.0060.00.3      ARTHPH_A              NaN
#
#                                            Description  Type   Location  \
# 0                                          Record type   Num      1 - 2
# 1         Year of the National Health Interview Survey   Num      3 - 6
# 2    Randomly assigned household number unique to a...  Char     7 - 13
# 3                                Weight - Final Annual   Num    14 - 23
# 4    2013 NCHS Urban-Rural Classification Scheme fo...   Num         24
# ..                                                 ...   ...        ...
# 957                       Arthritis pain, past 30 days   Num  530 - 531
# 958                     Arthritis activity limitations   Num        532
# 959                         Arthritis work limitations   Num        533
# 960                 Lose weight to help with arthritis   Num        534
# 961           Physical activity to help with arthritis   Num        535
#
#     Length   22   21   20 19
# 0        2    x    x    x  x
# 1        4    x    x    x  x
# 2        7    x    x    x  x
# 3       10    x    x    x  x
# 4        1    x    x    x  x
# ..     ...  ...  ...  ... ..
# 957      2  NaN  NaN  NaN  x
# 958      1  NaN  NaN  NaN  x
# 959      1  NaN  NaN  NaN  x
# 960      1  NaN  NaN  NaN  x
# 961      1  NaN  NaN  NaN  x
#
# [962 rows x 12 columns]

# %%
pdf_table = tabula.read_pdf('source/adult-codebook19.pdf', pages='all', multiple_tables=True, pandas_options={'header':'None'})
# Out:
# ---------------------------------------------------------------------------
# JVMNotFoundException                      Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pdf_table = tabula.read_pdf('source/adult-codebook19.pdf', pages='all', multiple_tables=True, pandas_options={'header':'None'})
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tabula\io.py:395, in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, use_raw_url, pages, guess, area, relative_area, lattice, stream, password, silent, columns, relative_columns, format, batch, output_path, force_subprocess, options)
#     392     raise ValueError(f"{path} is empty. Check the file, or download it manually.")
#     394 try:
# --> 395     output = _run(
#     396         tabula_options,
#     397         java_options,
#     398         path,
#     399         encoding=encoding,
#     400         force_subprocess=force_subprocess,
#     401     )
#     402 finally:
#     403     if temporary:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tabula\io.py:74, in _run(options, java_options, path, encoding, force_subprocess)
#      69     _tabula_vm = SubprocessTabula(
#      70         java_options=java_options, silent=options.silent, encoding=encoding
#      71     )
#      73 if not _tabula_vm:
# ---> 74     _tabula_vm = TabulaVm(java_options=java_options, silent=options.silent)
#      75     if _tabula_vm and not _tabula_vm.tabula:
#      76         _tabula_vm = SubprocessTabula(
#      77             java_options=java_options, silent=options.silent, encoding=encoding
#      78         )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tabula\backend.py:45, in TabulaVm.__init__(self, java_options, silent)
#      36     if silent:
#      37         java_options.extend(
#      38             (
#      39                 "-Dorg.slf4j.simpleLogger.defaultLogLevel=off",
#    (...)
#      42             )
#      43         )
# ---> 45     jpype.startJVM(*java_options, convertStrings=False)
#      47 import java.lang as lang
#      48 import technology.tabula as tabula
#
# File ~\AppData\Roaming\Python\Python311\site-packages\jpype\_core.py:219, in startJVM(jvmpath, classpath, ignoreUnrecognized, convertStrings, interrupt, *jvmargs)
#     216         jvmargs = jvmargs[1:]
#     218 if not jvmpath:
# --> 219     jvmpath = getDefaultJVMPath()
#     220 else:
#     221     # Allow the path to be a PathLike.
#     222     jvmpath = os.fspath(jvmpath)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\jpype\_jvmfinder.py:74, in getDefaultJVMPath()
#      72 else:
#      73     finder = LinuxJVMFinder()
# ---> 74 return finder.get_jvm_path()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\jpype\_jvmfinder.py:212, in JVMFinder.get_jvm_path(self)
#     210 if jvm_notsupport_ext is not None:
#     211     raise jvm_notsupport_ext
# --> 212 raise JVMNotFoundException("No JVM shared library file ({0}) "
#     213                            "found. Try setting up the JAVA_HOME "
#     214                            "environment variable properly."
#     215                            .format(self._libfile))
#
# JVMNotFoundException: No JVM shared library file (jvm.dll) found. Try setting up the JAVA_HOME environment variable properly.
